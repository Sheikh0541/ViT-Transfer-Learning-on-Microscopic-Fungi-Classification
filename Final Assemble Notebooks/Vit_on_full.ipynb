# %% [markdown]
# GPU

# %%
# !nvidia-smi
# Out:
# Mon Sep 18 10:08:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Importing Libraries

# %%
import tensorflow as tf
import os
import numpy as np
import random
from tqdm.auto import tqdm
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from glob import glob
import cv2
from skimage.io import imread, imshow, show

from tensorflow import keras
from keras import layers
from keras.callbacks import ModelCheckpoint

seed = 42
np.random.seed = seed  # To get same random seed everytime we run the whole thing.
random.seed(seed)

import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install -U tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.21.0 typeguard-2.13.3

# %%
import tensorflow_addons as tfa

# %% [markdown]
# ## Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data Preparation

# %%
H1_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H1/*"
H2_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H2/*"
H3_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H3/*"
H5_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H5/*"
H6_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H6/*"

# %%
def sorted_file_paths(path):
    file_paths = sorted(glob(path))
    print("Total image files:")
    print(f"{len(file_paths)} \n")
    return file_paths

H1_file_paths = sorted_file_paths(H1_path)
H2_file_paths = sorted_file_paths(H2_path)
H3_file_paths = sorted_file_paths(H3_path)
H5_file_paths = sorted_file_paths(H5_path)
H6_file_paths = sorted_file_paths(H6_path)
# Out:
# Total image files:
# 4357
#
# Total image files:
# 2314
#
# Total image files:
# 816
#
# Total image files:
# 814
#
# Total image files:
# 739

# %%
all_file_paths = H1_file_paths + H2_file_paths + H3_file_paths + H5_file_paths + H6_file_paths
print(len(all_file_paths))
print(4357+2314+816+814+739)
# Out:
# 9040
# 9040

# %%
def image_preprocess(paths):
    total = len(paths)
    im_array = np.zeros((total, 128, 128, 3), dtype = np.float32)
    for i in tqdm(range(total)):
        img = imread(paths[i])  # Numpy Array = (500,500,3)
        # print(image.shape)
        img = cv2.resize(img, (128, 128))
        img = img / 255.0
        im_array[i, :,:,:] = img
    return im_array

# X = image_preprocess(all_file_paths)
X = np.load("/content/drive/MyDrive/ICCIT 2023/npy_files/array_9040.npy")
print(X.shape)
print(X.dtype)
# Out:
# (9040, 128, 128, 3)
# float32

# %%
# np.save("/content/drive/MyDrive/ICCIT 2023/npy_files/array_9040.npy", X)

# %%
labels = ['H1']*4357 + ['H2']*2314 + ['H3']*816 + ['H5']*814 + ['H6']*739
print(type(labels))
print(len(labels))
# print(labels[3300])
# print(labels)
# Out:
# <class 'list'>
# 9040

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras

label_enconder = LabelEncoder()
y = label_enconder.fit_transform(labels)
print(y.shape)
print(y)
print('\n')


classes = list(label_enconder.classes_)
print(classes)
print('\n')
# Out:
# (9040,)
# [0 0 0 ... 4 4 4]
#
#
# ['H1', 'H2', 'H3', 'H5', 'H6']

# %%
X = np.array(X, dtype=np.float32)
y = np.array(y, dtype=np.float32)
print(X.shape, y.shape)
print(X.dtype, y.dtype)
# All are 4D and 1D array.
# Out:
# (9040, 128, 128, 3) (9040,)
# float32 float32

# %% [markdown]
# ## Model creation

# %%
input_shape = (128, 128, 3)
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 32
num_epochs = 100
image_size = 72
patch_size = 6
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 4
mlp_head_units = [2048, 1024]

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)

# Compute the mean and the variance of the training data for normalization.
# data_augmentation.layers[0].adapt(x_train)



def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches


class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier(layer):
    input_shape = (128, 128, 3)
    num_classes = 5

    inputs = layers.Input(shape=input_shape)

    augmented = layer(inputs)

    patches = Patches(patch_size)(augmented)

    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)


    for _ in range(transformer_layers):

        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)

        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1
        x2 = layers.Add()([attention_output, encoded_patches])

        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)

        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)

    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)

    logits = layers.Dense(num_classes, activation='softmax')(features)

    model = keras.Model(inputs=inputs, outputs=logits)

    return model

# %%
model = create_vit_classifier(data_augmentation)
model.summary()

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Training

# %%
def metric_calculation(true, out):

    f1_metric = tf.keras.metrics.F1Score()
    f1_metric.update_state(true, out)
    f1_scores = f1_metric.result().numpy()
    f1 = np.mean(f1_scores)

    pred = np.zeros((true.shape[0],5))
    for i in range(true.shape[0]):
        indx = np.argmax(out[i,:])
        pred[i,indx] = 1

    recall_scores = []
    pre_scores =[]
    for i in range(5):
        re_metric = tf.keras.metrics.Recall()
        pre_metric = tf.keras.metrics.Precision()
        re_metric.update_state(true[:,i],pred[:,i])
        pre_metric.update_state(true[:,i],pred[:,i])

        recall_scores.append(re_metric.result().numpy())
        pre_scores.append(pre_metric.result().numpy())

    recall = np.mean(np.array(recall_scores))
    precision = np.mean(np.array(pre_scores))

    return precision, recall, f1

# %%
# xx = np.array([[1, 0, 0],
#                [1, 0, 0],
#                [0, 1, 0],
#                [0, 0, 1]])
# yy = np.array([[0.9, 0.05, 0.05],
#                [0.1, 0.8, 0.1],
#                [0.2, 0.7, 0.1],
#                [0.2, 0.2, 0.6]])
# a, b, c = metric_calculation(xx, yy)
# print(a, b, c)

# %%
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

fold_no = 1
acc_per_fold = []
history_all = []
f1_all = []
pre_all = []
rec_all = []

for train, test in cv.split(X, y):

    print('   ')
    print(f'Training for fold {fold_no} ...', '\n')

    x_train = X[train]
    x_test = X[test]
    y_train = y[train]
    y_test = y[test]

    y_train = tf.keras.utils.to_categorical(y_train, num_classes=5)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=5)

    data_augmentation = keras.Sequential([layers.Normalization(),
                                          layers.Resizing(image_size, image_size),
                                          layers.RandomFlip("horizontal"),
                                          layers.RandomRotation(factor=0.02),
                                          layers.RandomZoom(height_factor=0.2, width_factor=0.2)],
                                          name="data_augmentation")


    data_augmentation.layers[0].adapt(x_train)

    model = create_vit_classifier(data_augmentation)

    optimizer = tfa.optimizers.AdamW(learning_rate=learning_rate,
                                     weight_decay=weight_decay)

    model.compile(optimizer=optimizer,
                  loss=keras.losses.CategoricalCrossentropy(from_logits=True),
                  metrics=[keras.metrics.CategoricalAccuracy(name="accuracy")])


    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data = (x_test, y_test))

    _, accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%", '\n')

    prediction = model.predict(x_test)
    pre, rec, f1 = metric_calculation(y_test, prediction)

    print(f"F1 Score: {round(f1 * 100, 2)}%", '\n')
    print(f"Precision: {round(pre * 100, 2)}%", '\n')
    print(f"Recall: {round(rec * 100, 2)}%", '\n')

    acc_per_fold.append(accuracy*100)
    f1_all.append(f1)
    pre_all.append(pre)
    rec_all.append(rec)
    history_all.append(history)

    fold_no = fold_no + 1
# Out:
#
# Training for fold 1 ...
#
# Epoch 1/100
# 226/226 [==============================] - 13s 26ms/step - loss: 1.8155 - accuracy: 0.5065 - val_loss: 0.8809 - val_accuracy: 0.6515
# Epoch 2/100
# 226/226 [==============================] - 4s 19ms/step - loss: 1.0182 - accuracy: 0.5902 - val_loss: 0.8154 - val_accuracy: 0.6681
# Epoch 3/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.9169 - accuracy: 0.6246 - val_loss: 0.8965 - val_accuracy: 0.6527
# Epoch 4/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8617 - accuracy: 0.6452 - val_loss: 0.8499 - val_accuracy: 0.6554
# Epoch 5/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8587 - accuracy: 0.6478 - val_loss: 0.7633 - val_accuracy: 0.7058
# Epoch 6/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8206 - accuracy: 0.6633 - val_loss: 0.7201 - val_accuracy: 0.7058
# Epoch 7/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8004 - accuracy: 0.6722 - val_loss: 0.7326 - val_accuracy: 0.7118
# Epoch 8/100
# 226/226 [==============================] - 4s 18ms/step - loss: 0.7633 - accuracy: 0.6915 - val_loss: 0.7024 - val_accuracy: 0.7085
# Epoch 9/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7746 - accuracy: 0.6856 - val_loss: 0.6780 - val_accuracy: 0.7273
# Epoch 10/100
# 226/226 [==============================] - 4s 20ms/step - loss: 0.7336 - accuracy: 0.6979 - val_loss: 0.6787 - val_accuracy: 0.7257
# Epoch 11/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7173 - accuracy: 0.7058 - val_loss: 0.6667 - val_accuracy: 0.7378
# Epoch 12/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7100 - accuracy: 0.7147 - val_loss: 0.6458 - val_accuracy: 0.7351
# Epoch 13/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6861 - accuracy: 0.7194 - val_loss: 0.6700 - val_accuracy: 0.7246
# Epoch 14/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6609 - accuracy: 0.7340 - val_loss: 0.6580 - val_accuracy: 0.7389
# Epoch 15/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6590 - accuracy: 0.7272 - val_loss: 0.6616 - val_accuracy: 0.7290
# Epoch 16/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6629 - accuracy: 0.7287 - val_loss: 0.6421 - val_accuracy: 0.7450
# Epoch 17/100
# 226/226 [==============================] - 4s 18ms/step - loss: 0.6271 - accuracy: 0.7479 - val_loss: 0.6332 - val_accuracy: 0.7611
# Epoch 18/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6402 - accuracy: 0.7388 - val_loss: 0.6564 - val_accuracy: 0.7506
# Epoch 19/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6164 - accuracy: 0.7518 - val_loss: 0.6691 - val_accuracy: 0.7533
# Epoch 20/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5867 - accuracy: 0.7659 - val_loss: 0.6354 - val_accuracy: 0.7555
# Epoch 21/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6022 - accuracy: 0.7529 - val_loss: 0.6799 - val_accuracy: 0.6748
# Epoch 22/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5961 - accuracy: 0.7541 - val_loss: 0.5940 - val_accuracy: 0.7683
# Epoch 23/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5642 - accuracy: 0.7718 - val_loss: 0.6130 - val_accuracy: 0.7561
# Epoch 24/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5649 - accuracy: 0.7752 - val_loss: 0.6051 - val_accuracy: 0.7743
# Epoch 25/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5729 - accuracy: 0.7749 - val_loss: 0.5842 - val_accuracy: 0.7688
# Epoch 26/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5670 - accuracy: 0.7695 - val_loss: 0.6373 - val_accuracy: 0.7600
# Epoch 27/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5684 - accuracy: 0.7739 - val_loss: 0.5638 - val_accuracy: 0.7804
# Epoch 28/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5445 - accuracy: 0.7772 - val_loss: 0.6149 - val_accuracy: 0.7644
# Epoch 29/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.
100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2377 - accuracy: 0.9158 - val_loss: 0.6046 - val_accuracy: 0.8285
# Epoch 91/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2376 - accuracy: 0.9158 - val_loss: 0.6939 - val_accuracy: 0.8136
# Epoch 92/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2191 - accuracy: 0.9184 - val_loss: 0.5949 - val_accuracy: 0.8125
# Epoch 93/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2125 - accuracy: 0.9227 - val_loss: 0.5836 - val_accuracy: 0.8230
# Epoch 94/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2243 - accuracy: 0.9191 - val_loss: 0.6332 - val_accuracy: 0.8191
# Epoch 95/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2136 - accuracy: 0.9235 - val_loss: 0.6667 - val_accuracy: 0.8119
# Epoch 96/100
# 226/226 [==============================] - 5s 21ms/step - loss: 0.2152 - accuracy: 0.9212 - val_loss: 0.6149 - val_accuracy: 0.8202
# Epoch 97/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2414 - accuracy: 0.9145 - val_loss: 0.6977 - val_accuracy: 0.8103
# Epoch 98/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2120 - accuracy: 0.9195 - val_loss: 0.5907 - val_accuracy: 0.8136
# Epoch 99/100
# 226/226 [==============================] - 4s 20ms/step - loss: 0.2062 - accuracy: 0.9277 - val_loss: 0.6251 - val_accuracy: 0.8241
# Epoch 100/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2210 - accuracy: 0.9208 - val_loss: 0.6910 - val_accuracy: 0.8147
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6910 - accuracy: 0.8147
# Test accuracy: 81.47%
#
# 57/57 [==============================] - 1s 9ms/step
# F1 Score: 82.45%
#
# Precision: 83.45%
#
# Recall: 81.61%
#
#
# Training for fold 2 ...
#
# Epoch 1/100
# 226/226 [==============================] - 11s 25ms/step - loss: 1.8113 - accuracy: 0.5151 - val_loss: 0.8756 - val_accuracy: 0.6504
# Epoch 2/100
# 226/226 [==============================] - 4s 18ms/step - loss: 0.9968 - accuracy: 0.6019 - val_loss: 0.8517 - val_accuracy: 0.6416
# Epoch 3/100
# 226/226 [==============================] - 4s 18ms/step - loss: 0.9032 - accuracy: 0.6376 - val_loss: 0.8001 - val_accuracy: 0.6864
# Epoch 4/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8645 - accuracy: 0.6467 - val_loss: 0.8218 - val_accuracy: 0.6781
# Epoch 5/100
# 226/226 [==============================] - 4s 18ms/step - loss: 0.8219 - accuracy: 0.6733 - val_loss: 0.7734 - val_accuracy: 0.6914
# Epoch 6/100
# 226/226 [==============================] - 4s 18ms/step - loss: 0.8239 - accuracy: 0.6715 - val_loss: 0.7553 - val_accuracy: 0.7030
# Epoch 7/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8062 - accuracy: 0.6803 - val_loss: 0.7819 - val_accuracy: 0.6654
# Epoch 8/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7745 - accuracy: 0.6950 - val_loss: 0.7239 - val_accuracy: 0.7069
# Epoch 9/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7545 - accuracy: 0.6952 - val_loss: 0.7551 - val_accuracy: 0.6969
# Epoch 10/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7245 - accuracy: 0.7160 - val_loss: 0.7170 - val_accuracy: 0.7041
# Epoch 11/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7132 - accuracy: 0.7200 - val_loss: 0.6762 - val_accuracy: 0.7356
# Epoch 12/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6991 - accuracy: 0.7257 - val_loss: 0.6846 - val_accuracy: 0.7273
# Epoch 13/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6790 - accuracy: 0.7348 - val_loss: 0.6606 - val_accuracy: 0.7417
# Epoch 14/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6739 - accuracy: 0.7409 - val_loss: 0.7072 - val_accuracy: 0.7240
# Epoch 15/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6740 - accuracy: 0.7359 - val_loss: 0.6569 - val_accuracy: 0.7461
# Epoch 16/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6388 - accuracy: 0.7533 - val_loss: 0.6824 - val_accuracy: 0.7351
# Epoch 17/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6334 - accuracy: 0.7571 - val_loss: 0.6524 - val_accuracy: 0.7483
# Epoch 18/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.
100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2353 - accuracy: 0.9115 - val_loss: 0.6148 - val_accuracy: 0.8269
# Epoch 80/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2680 - accuracy: 0.9061 - val_loss: 0.5825 - val_accuracy: 0.8357
# Epoch 81/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2380 - accuracy: 0.9118 - val_loss: 0.6639 - val_accuracy: 0.8230
# Epoch 82/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2518 - accuracy: 0.9068 - val_loss: 0.6585 - val_accuracy: 0.7987
# Epoch 83/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2728 - accuracy: 0.9006 - val_loss: 0.5997 - val_accuracy: 0.8225
# Epoch 84/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2677 - accuracy: 0.9069 - val_loss: 0.6519 - val_accuracy: 0.8247
# Epoch 85/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2382 - accuracy: 0.9130 - val_loss: 0.6524 - val_accuracy: 0.8368
# Epoch 86/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2520 - accuracy: 0.9056 - val_loss: 0.5511 - val_accuracy: 0.8236
# Epoch 87/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2273 - accuracy: 0.9166 - val_loss: 0.5791 - val_accuracy: 0.8296
# Epoch 88/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2518 - accuracy: 0.9134 - val_loss: 0.5607 - val_accuracy: 0.8346
# Epoch 89/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2507 - accuracy: 0.9108 - val_loss: 0.5878 - val_accuracy: 0.8175
# Epoch 90/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2544 - accuracy: 0.9097 - val_loss: 0.5560 - val_accuracy: 0.8379
# Epoch 91/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2276 - accuracy: 0.9179 - val_loss: 0.5678 - val_accuracy: 0.8269
# Epoch 92/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2187 - accuracy: 0.9205 - val_loss: 0.5900 - val_accuracy: 0.8197
# Epoch 93/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2382 - accuracy: 0.9165 - val_loss: 0.5759 - val_accuracy: 0.8313
# Epoch 94/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2119 - accuracy: 0.9217 - val_loss: 0.5862 - val_accuracy: 0.8225
# Epoch 95/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2330 - accuracy: 0.9155 - val_loss: 0.5974 - val_accuracy: 0.8158
# Epoch 96/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2453 - accuracy: 0.9173 - val_loss: 0.5883 - val_accuracy: 0.8324
# Epoch 97/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2303 - accuracy: 0.9184 - val_loss: 0.5900 - val_accuracy: 0.8197
# Epoch 98/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2265 - accuracy: 0.9165 - val_loss: 0.6118 - val_accuracy: 0.8324
# Epoch 99/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2452 - accuracy: 0.9125 - val_loss: 0.6961 - val_accuracy: 0.7942
# Epoch 100/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2268 - accuracy: 0.9165 - val_loss: 0.6402 - val_accuracy: 0.8285
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6402 - accuracy: 0.8285
# Test accuracy: 82.85%
#
# 57/57 [==============================] - 1s 10ms/step
# F1 Score: 82.81%
#
# Precision: 86.47%
#
# Recall: 80.35%
#
#
# Training for fold 3 ...
#
# Epoch 1/100
# 226/226 [==============================] - 10s 25ms/step - loss: 1.8596 - accuracy: 0.5171 - val_loss: 1.0390 - val_accuracy: 0.5548
# Epoch 2/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.9820 - accuracy: 0.6091 - val_loss: 0.8726 - val_accuracy: 0.6466
# Epoch 3/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.9120 - accuracy: 0.6312 - val_loss: 0.7961 - val_accuracy: 0.6643
# Epoch 4/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8523 - accuracy: 0.6587 - val_loss: 0.7418 - val_accuracy: 0.6969
# Epoch 5/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8258 - accuracy: 0.6654 - val_loss: 0.7838 - val_accuracy: 0.6869
# Epoch 6/100
# 226/226 [==============================] - 5s 20ms/step - loss: 0.8215 - accuracy: 0.6782 - val_loss: 0.7241 - val_accuracy: 0.6925
# Epoch 7/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.
100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2429 - accuracy: 0.9150 - val_loss: 0.5512 - val_accuracy: 0.8158
# Epoch 97/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2264 - accuracy: 0.9162 - val_loss: 0.5613 - val_accuracy: 0.8341
# Epoch 98/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2282 - accuracy: 0.9184 - val_loss: 0.5419 - val_accuracy: 0.8319
# Epoch 99/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2325 - accuracy: 0.9209 - val_loss: 0.7186 - val_accuracy: 0.8031
# Epoch 100/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2216 - accuracy: 0.9216 - val_loss: 0.5865 - val_accuracy: 0.8169
# 57/57 [==============================] - 1s 11ms/step - loss: 0.5865 - accuracy: 0.8169
# Test accuracy: 81.69%
#
# 57/57 [==============================] - 1s 10ms/step
# F1 Score: 80.98%
#
# Precision: 84.67%
#
# Recall: 78.54%
#
#
# Training for fold 4 ...
#
# Epoch 1/100
# 226/226 [==============================] - 11s 26ms/step - loss: 1.8009 - accuracy: 0.5248 - val_loss: 0.9664 - val_accuracy: 0.5586
# Epoch 2/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.9665 - accuracy: 0.6094 - val_loss: 0.8354 - val_accuracy: 0.6449
# Epoch 3/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8938 - accuracy: 0.6388 - val_loss: 0.7947 - val_accuracy: 0.6737
# Epoch 4/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8469 - accuracy: 0.6630 - val_loss: 0.7852 - val_accuracy: 0.6709
# Epoch 5/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8203 - accuracy: 0.6723 - val_loss: 0.7405 - val_accuracy: 0.6980
# Epoch 6/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8030 - accuracy: 0.6766 - val_loss: 0.7242 - val_accuracy: 0.6986
# Epoch 7/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7818 - accuracy: 0.6818 - val_loss: 0.7321 - val_accuracy: 0.7124
# Epoch 8/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7609 - accuracy: 0.6921 - val_loss: 0.6902 - val_accuracy: 0.7174
# Epoch 9/100
# 226/226 [==============================] - 4s 20ms/step - loss: 0.7503 - accuracy: 0.7006 - val_loss: 0.6995 - val_accuracy: 0.7201
# Epoch 10/100
# 226/226 [==============================] - 4s 20ms/step - loss: 0.7198 - accuracy: 0.7088 - val_loss: 0.7221 - val_accuracy: 0.7146
# Epoch 11/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7126 - accuracy: 0.7105 - val_loss: 0.6835 - val_accuracy: 0.7295
# Epoch 12/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6908 - accuracy: 0.7255 - val_loss: 0.6610 - val_accuracy: 0.7329
# Epoch 13/100
# 226/226 [==============================] - 4s 20ms/step - loss: 0.6872 - accuracy: 0.7324 - val_loss: 0.7196 - val_accuracy: 0.7024
# Epoch 14/100
# 226/226 [==============================] - 5s 20ms/step - loss: 0.6546 - accuracy: 0.7313 - val_loss: 0.7001 - val_accuracy: 0.7223
# Epoch 15/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6437 - accuracy: 0.7449 - val_loss: 0.7051 - val_accuracy: 0.7472
# Epoch 16/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6436 - accuracy: 0.7460 - val_loss: 0.6316 - val_accuracy: 0.7467
# Epoch 17/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6168 - accuracy: 0.7569 - val_loss: 0.6505 - val_accuracy: 0.7406
# Epoch 18/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6051 - accuracy: 0.7598 - val_loss: 0.5922 - val_accuracy: 0.7649
# Epoch 19/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5924 - accuracy: 0.7665 - val_loss: 0.5989 - val_accuracy: 0.7594
# Epoch 20/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5977 - accuracy: 0.7631 - val_loss: 0.6781 - val_accuracy: 0.7417
# Epoch 21/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5709 - accuracy: 0.7692 - val_loss: 0.6294 - val_accuracy: 0.7677
# Epoch 22/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5540 - accuracy: 0.7801 - val_loss: 0.6159 - val_accuracy: 0.7660
# Epoch 23/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5428 - accuracy: 0.7782 - val_loss: 0.6405 - val_accuracy: 0.7683
# Epoch 24/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5374 - accuracy: 0.7894 - val_loss: 0.6802 - val_accuracy: 0.7351
# Epoch 25/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.5300 - accuracy: 0.7889 - val_loss: 0.6098 - val_accuracy: 0.7694
# Epoch 26/100
# ...
# Epoch 94/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2315 - accuracy: 0.9188 - val_loss: 0.6676 - val_accuracy: 0.8197
# Epoch 95/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2356 - accuracy: 0.9173 - val_loss: 0.5967 - val_accuracy: 0.8186
# Epoch 96/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2026 - accuracy: 0.9281 - val_loss: 0.7352 - val_accuracy: 0.8059
# Epoch 97/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2561 - accuracy: 0.9121 - val_loss: 0.6196 - val_accuracy: 0.8142
# Epoch 98/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2515 - accuracy: 0.9125 - val_loss: 0.6280 - val_accuracy: 0.7992
# Epoch 99/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2285 - accuracy: 0.9219 - val_loss: 0.5781 - val_accuracy: 0.8219
# Epoch 100/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2106 - accuracy: 0.9241 - val_loss: 0.6458 - val_accuracy: 0.8147
# 57/57 [==============================] - 1s 11ms/step - loss: 0.6458 - accuracy: 0.8147
# Test accuracy: 81.47%
#
# 57/57 [==============================] - 1s 9ms/step
# F1 Score: 80.52%
#
# Precision: 85.57%
#
# Recall: 77.02%
#
#
# Training for fold 5 ...
#
# Epoch 1/100
# 226/226 [==============================] - 10s 25ms/step - loss: 1.8443 - accuracy: 0.5181 - val_loss: 0.9682 - val_accuracy: 0.5962
# Epoch 2/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.9751 - accuracy: 0.6156 - val_loss: 0.8580 - val_accuracy: 0.6427
# Epoch 3/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8751 - accuracy: 0.6433 - val_loss: 0.8047 - val_accuracy: 0.6864
# Epoch 4/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8488 - accuracy: 0.6551 - val_loss: 0.7524 - val_accuracy: 0.6936
# Epoch 5/100
# 226/226 [==============================] - 4s 20ms/step - loss: 0.8384 - accuracy: 0.6634 - val_loss: 0.7536 - val_accuracy: 0.6798
# Epoch 6/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.8344 - accuracy: 0.6694 - val_loss: 0.8435 - val_accuracy: 0.6383
# Epoch 7/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7802 - accuracy: 0.6817 - val_loss: 0.7510 - val_accuracy: 0.6908
# Epoch 8/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7887 - accuracy: 0.6822 - val_loss: 0.6848 - val_accuracy: 0.7146
# Epoch 9/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7517 - accuracy: 0.6948 - val_loss: 0.6781 - val_accuracy: 0.7174
# Epoch 10/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7638 - accuracy: 0.6926 - val_loss: 0.7080 - val_accuracy: 0.7074
# Epoch 11/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7188 - accuracy: 0.7118 - val_loss: 0.7294 - val_accuracy: 0.7008
# Epoch 12/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7211 - accuracy: 0.7143 - val_loss: 0.7373 - val_accuracy: 0.7201
# Epoch 13/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.7100 - accuracy: 0.7204 - val_loss: 0.6784 - val_accuracy: 0.7163
# Epoch 14/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6823 - accuracy: 0.7284 - val_loss: 0.6648 - val_accuracy: 0.7212
# Epoch 15/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6870 - accuracy: 0.7313 - val_loss: 0.6653 - val_accuracy: 0.7223
# Epoch 16/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6724 - accuracy: 0.7322 - val_loss: 0.6154 - val_accuracy: 0.7555
# Epoch 17/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.6546 - accuracy: 0.7381 - val_loss: 0.6158 - val_accuracy: 0.7478
# Epoch 18/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.
100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2558 - accuracy: 0.9067 - val_loss: 0.6488 - val_accuracy: 0.8125
# Epoch 81/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2600 - accuracy: 0.9051 - val_loss: 0.6161 - val_accuracy: 0.8153
# Epoch 82/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2471 - accuracy: 0.9127 - val_loss: 0.6021 - val_accuracy: 0.8202
# Epoch 83/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2585 - accuracy: 0.9072 - val_loss: 0.5744 - val_accuracy: 0.8147
# Epoch 84/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2298 - accuracy: 0.9154 - val_loss: 0.6042 - val_accuracy: 0.8164
# Epoch 85/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2477 - accuracy: 0.9071 - val_loss: 0.6718 - val_accuracy: 0.7865
# Epoch 86/100
# 226/226 [==============================] - 4s 18ms/step - loss: 0.2594 - accuracy: 0.9105 - val_loss: 0.5955 - val_accuracy: 0.8114
# Epoch 87/100
# 226/226 [==============================] - 4s 18ms/step - loss: 0.2558 - accuracy: 0.9080 - val_loss: 0.5607 - val_accuracy: 0.8208
# Epoch 88/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2495 - accuracy: 0.9105 - val_loss: 0.5471 - val_accuracy: 0.8158
# Epoch 89/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2415 - accuracy: 0.9126 - val_loss: 0.5985 - val_accuracy: 0.8230
# Epoch 90/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2252 - accuracy: 0.9175 - val_loss: 0.6104 - val_accuracy: 0.8081
# Epoch 91/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2304 - accuracy: 0.9183 - val_loss: 0.6312 - val_accuracy: 0.8103
# Epoch 92/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2874 - accuracy: 0.9003 - val_loss: 0.6235 - val_accuracy: 0.7948
# Epoch 93/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2418 - accuracy: 0.9097 - val_loss: 0.6010 - val_accuracy: 0.8131
# Epoch 94/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2179 - accuracy: 0.9222 - val_loss: 0.6860 - val_accuracy: 0.8153
# Epoch 95/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2346 - accuracy: 0.9139 - val_loss: 0.6875 - val_accuracy: 0.7987
# Epoch 96/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2229 - accuracy: 0.9158 - val_loss: 0.7245 - val_accuracy: 0.8009
# Epoch 97/100
# 226/226 [==============================] - 4s 20ms/step - loss: 0.2217 - accuracy: 0.9208 - val_loss: 0.6011 - val_accuracy: 0.8070
# Epoch 98/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2268 - accuracy: 0.9159 - val_loss: 0.6864 - val_accuracy: 0.7793
# Epoch 99/100
# 226/226 [==============================] - 4s 18ms/step - loss: 0.2565 - accuracy: 0.9127 - val_loss: 0.5768 - val_accuracy: 0.8108
# Epoch 100/100
# 226/226 [==============================] - 4s 19ms/step - loss: 0.2254 - accuracy: 0.9163 - val_loss: 0.6442 - val_accuracy: 0.8025
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6442 - accuracy: 0.8025
# Test accuracy: 80.25%
#
# 57/57 [==============================] - 1s 9ms/step
# F1 Score: 80.08%
#
# Precision: 81.76%
#
# Recall: 79.03%

# %% [markdown]
# ## Analysis

# %%
print(acc_per_fold, '\n')

mean = np.mean(np.array(acc_per_fold))
std = np.std(np.array(acc_per_fold))

print(f"Overall Accuracy is : {mean}+-{std}")
# Out:
# [81.4712405204773, 82.85398483276367, 81.69247508049011, 81.4712405204773, 80.25442361831665]
#
# Overall Accuracy is : 81.548672914505+-0.8260255515253636

# %%
print(f1_all, '\n')

mean = np.mean(np.array(f1_all))
std = np.std(np.array(f1_all))

print(f"F1 Score is : {mean}+-{std}")
# Out:
# [0.82445115, 0.8281032, 0.8097852, 0.8052246, 0.8008013]
#
# F1 Score is : 0.8136730194091797+-0.010738440789282322

# %%
print(pre_all, '\n')

mean = np.mean(np.array(pre_all))
std = np.std(np.array(pre_all))

print(f"Precision is : {mean}+-{std}")
# Out:
# [0.8345336, 0.8647251, 0.8467291, 0.8557221, 0.8176098]
#
# Precision is : 0.8438639640808105+-0.016494547948241234

# %%
print(rec_all, '\n')

mean = np.mean(np.array(rec_all))
std = np.std(np.array(rec_all))

print(f"Recall is : {mean}+-{std}")
# Out:
# [0.81605417, 0.80347615, 0.78544426, 0.77019465, 0.79032063]
#
# Recall is : 0.7930979132652283+-0.01565598137676716

# %% [markdown]
# ## History an File Saving to Numpy Array

# %%
history_nparray = np.zeros((20, 100))
print(len(history_all[0].history))

count = 0

for k in tqdm(range(5)):

    aa = history_all[k].history      # Dictionary

    history_nparray[count, :] = np.array(aa['loss'])
    count = count+1
    history_nparray[count, :] = np.array(aa['accuracy'])
    count = count+1
    history_nparray[count, :] = np.array(aa['val_loss'])
    count = count+1
    history_nparray[count, :] = np.array(aa['val_accuracy'])
    count = count+1

print(count)
print(history_nparray[-1,:])
# Out:
# 4
#   0%|          | 0/5 [00:00<?, ?it/s]
# 20
# [0.59623891 0.64269912 0.6863938  0.69358408 0.67975664 0.63827431
#  0.69081861 0.71460176 0.71736723 0.70741153 0.70077431 0.72013277
#  0.71626109 0.72123891 0.72234511 0.75553095 0.74778759 0.72621679
#  0.74115044 0.73949116 0.73396015 0.76659292 0.75884956 0.71681416
#  0.75829649 0.75663716 0.75884956 0.75995576 0.77378321 0.7715708
#  0.76106197 0.75995576 0.75553095 0.78373891 0.77710176 0.79037613
#  0.78650445 0.77820796 0.78373891 0.78207964 0.79535401 0.77654868
#  0.78097343 0.78539824 0.81305307 0.77654868 0.79756635 0.80475664
#  0.79756635 0.80254424 0.80530971 0.7920354  0.7909292  0.80088496
#  0.75663716 0.80088496 0.79922569 0.80475664 0.81581861 0.80254424
#  0.79037613 0.81747788 0.81028759 0.8136062  0.79867256 0.8136062
#  0.81803095 0.8113938  0.8125     0.81803095 0.81803095 0.80254424
#  0.80365044 0.80918139 0.80696905 0.77876109 0.82300884 0.81084073
#  0.81471241 0.8125     0.81526548 0.82024336 0.81471241 0.81637168
#  0.78650445 0.8113938  0.82079649 0.81581861 0.82300884 0.80807525
#  0.81028759 0.79480088 0.81305307 0.81526548 0.79867256 0.80088496
#  0.80696905 0.77931416 0.81084073 0.80254424]

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(100), history_nparray[5,:], label='Training Accuracy')
plt.plot(range(100), history_nparray[7,:], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(100), history_nparray[4,:], label='Training Loss')
plt.plot(range(100), history_nparray[6,:], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
np.save('/content/ViT_9040_History.npy', history_nparray)

acc_f1_pre_rec = np.zeros((4,5))
acc_f1_pre_rec[0,:] = np.array(acc_per_fold)
acc_f1_pre_rec[1,:] = np.array(f1_all)
acc_f1_pre_rec[2,:] = np.array(pre_all)
acc_f1_pre_rec[3,:] = np.array(rec_all)

np.save('/content/ViT_9040_Acc_F1_Pre_Rec.npy', acc_f1_pre_rec)
