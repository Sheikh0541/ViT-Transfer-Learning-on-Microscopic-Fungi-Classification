# %% [markdown]
# GPU

# %%
# !nvidia-smi
# Out:
# Tue Sep 19 14:48:31 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Importing Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf
import os
import numpy as np
import random
from tqdm.auto import tqdm
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from glob import glob
import cv2
from skimage.io import imread, imshow, show

from tensorflow import keraskeras
from keras import layers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

seed = 42
np.random.seed = seed  # To get same random seed everytime we run the whole thing.
tf.random.set_seed(42)
random.seed(seed)

# %%
# !pip install -U tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.21.0 typeguard-2.13.3

# %%
import tensorflow_addons as tfa

# %% [markdown]
# ## Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data Preparation

# %%
H1_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H1/*"
H2_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H2/*"
H3_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H3/*"
H5_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H5/*"
H6_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H6/*"

# %%
def sorted_file_paths(path):
    file_paths = sorted(glob(path))
    print("Total image files:")
    print(f"{len(file_paths)} \n")
    return file_paths

H1_file_paths = sorted_file_paths(H1_path)
H2_file_paths = sorted_file_paths(H2_path)
H3_file_paths = sorted_file_paths(H3_path)
H5_file_paths = sorted_file_paths(H5_path)
H6_file_paths = sorted_file_paths(H6_path)
# Out:
# Total image files:
# 4357
#
# Total image files:
# 2314
#
# Total image files:
# 816
#
# Total image files:
# 814
#
# Total image files:
# 739

# %%
all_file_paths = H1_file_paths + H2_file_paths + H3_file_paths + H5_file_paths + H6_file_paths
print(len(all_file_paths))
print(4357+2314+816+814+739)
# Out:
# 9040
# 9040

# %%
def image_preprocess(paths):
    total = len(paths)
    im_array = np.zeros((total, 224, 224, 3), dtype = np.float32)
    for i in tqdm(range(total)):
        img = imread(paths[i])  # Numpy Array = (500,500,3)
        # print(image.shape)
        img = cv2.resize(img, (224, 224))
        # img = img / 255.0
        im_array[i, :,:,:] = img
    return im_array

# X = image_preprocess(all_file_paths)
X = np.load("/content/drive/MyDrive/ICCIT 2023/npy_files/array_9040_224.npy")
print(X.shape)
print(X.dtype)
# Out:
# (9040, 224, 224, 3)
# float32

# %%
# np.save("/content/drive/MyDrive/ICCIT 2023/npy_files/array_9040_224.npy", X)

# %%
labels = ['H1']*4357 + ['H2']*2314 + ['H3']*816 + ['H5']*814 + ['H6']*739
print(type(labels))
print(len(labels))
# print(labels[3300])
# print(labels)
# Out:
# <class 'list'>
# 9040

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras

label_enconder = LabelEncoder()
y = label_enconder.fit_transform(labels)
print(y.shape)
print(y)
print('\n')


classes = list(label_enconder.classes_)
print(classes)
print('\n')
# Out:
# (9040,)
# [0 0 0 ... 4 4 4]
#
#
# ['H1', 'H2', 'H3', 'H5', 'H6']

# %%
X = np.array(X, dtype=np.float32)
y = np.array(y, dtype=np.float32)
print(X.shape, y.shape)
print(X.dtype, y.dtype)
# All are 4D and 1D array.
# Out:
# (9040, 224, 224, 3) (9040,)
# float32 float32

# %% [markdown]
# ## Vit Model creation

# %%
input_size = 224
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 32
num_epochs = 100
image_size = 72
patch_size = 6
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 4
mlp_head_units = [2048, 1024]

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)

# Compute the mean and the variance of the training data for normalization.
# data_augmentation.layers[0].adapt(x_train)



def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches


class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_part(input, aug_layer):

    # input_shape = (input_size, input_size, 3)
    # num_classes = 5
    # inputs = layers.Input(shape=input_shape)
    # Augment data.

    augmented = aug_layer(input)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)  #9216
    # Add MLP.
    # features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    # logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    # model = keras.Model(inputs=inputs, outputs=logits)

    x = layers.Dense(2048, activation=tf.nn.gelu)(representation)

    return x  #2048

# vit_model = create_vit_classifier(data_augmentation)
# vit_model.summary()

# %% [markdown]
# ## Transfer Learning Model

# %%
def transfer_model(input):

    base_model = tf.keras.applications.resnet50.ResNet50(
                                                include_top=False,
                                                weights='imagenet',
                                                input_shape=(input_size, input_size, 3),
                                                pooling=None)

    base_model.trainable = False

    data_augmentation_resnet = keras.Sequential([layers.RandomFlip("horizontal"),
                                          layers.RandomRotation(factor=0.02),
                                          layers.RandomZoom(height_factor=0.1, width_factor=0.1)],
                                          name="resnet_augmentation")

    resnet_preprocess = tf.keras.applications.resnet50.preprocess_input(input)
    x = data_augmentation_resnet(resnet_preprocess)
    x = base_model(x, training=False)

    x = layers.GlobalAveragePooling2D()(x)
    # x = layers.Dropout(0.2)(x)
    # x = tf.keras.layers.Dense(1024,activation='relu')(x)
    # x = tf.keras.layers.Dropout(0.6)(x)
    # x = tf.keras.layers.Dense(512,activation='relu')(x)
    # x = tf.keras.layers.Dropout(0.5)(x)
    # output = tf.keras.layers.Dense(no_class, activation="softmax")(x)

    # model = keras.Model(inputs = input, outputs = output)

    return x

# model = creat_model()
# print(model.summary())

# %% [markdown]
# ## Casceding Model Creation

# %%
def Cascade_model(Vit_aug_layer):

    input = keras.Input(shape=(input_size, input_size, 3))  # (None, 224, 224, 3)
    num_classes = 5

    vit_output = create_vit_part(input, Vit_aug_layer)       #(None, 2048)
    tranfer_output = transfer_model(input)    #(None, 2048)

    multiplied = layers.Multiply()([vit_output, tranfer_output])
    x = layers.Dropout(0.5)(multiplied)

    x = tf.keras.layers.Dense(1024,activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(512,activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)

    output = tf.keras.layers.Dense(num_classes, activation="softmax")(x)

    model = keras.Model(inputs = input, outputs = output)

    return model

# %%
model = Cascade_model(data_augmentation)
model.summary()

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Training

# %%
def metric_calculation(true, out):

    f1_metric = tf.keras.metrics.F1Score()
    f1_metric.update_state(true, out)
    f1_scores = f1_metric.result().numpy()
    f1 = np.mean(f1_scores)

    pred = np.zeros((true.shape[0],5))
    for i in range(true.shape[0]):
        indx = np.argmax(out[i,:])
        pred[i,indx] = 1

    recall_scores = []
    pre_scores =[]
    for i in range(5):
        re_metric = tf.keras.metrics.Recall()
        pre_metric = tf.keras.metrics.Precision()
        re_metric.update_state(true[:,i],pred[:,i])
        pre_metric.update_state(true[:,i],pred[:,i])

        recall_scores.append(re_metric.result().numpy())
        pre_scores.append(pre_metric.result().numpy())

    recall = np.mean(np.array(recall_scores))
    precision = np.mean(np.array(pre_scores))

    return precision, recall, f1

# %%
acc_per_fold = []
history_all = []
f1_all = []
pre_all = []
rec_all = []

# %%
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

fold_no = 1


for train, test in cv.split(X, y):

    print('   ')
    print(f'Training for fold {fold_no} ...', '\n')

    x_train = X[train]
    x_test = X[test]
    y_train = y[train]
    y_test = y[test]

    y_train = tf.keras.utils.to_categorical(y_train, num_classes=5)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=5)

    data_augmentation_Vit = keras.Sequential([layers.Normalization(),
                                          layers.Resizing(image_size, image_size),
                                          layers.RandomFlip("horizontal"),
                                          layers.RandomRotation(factor=0.02),
                                          layers.RandomZoom(height_factor=0.2, width_factor=0.2)],
                                          name="vit_augmentation")


    data_augmentation_Vit.layers[0].adapt(x_train)

    model = Cascade_model(data_augmentation_Vit)

    optimizer = tfa.optimizers.AdamW(learning_rate=learning_rate,
                                     weight_decay=weight_decay)

    model.compile(optimizer=optimizer,
                  loss=keras.losses.CategoricalCrossentropy(from_logits=True),
                  metrics=[keras.metrics.CategoricalAccuracy(name="accuracy")])


    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data = (x_test, y_test))

    _, accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%", '\n')

    prediction = model.predict(x_test)
    pre, rec, f1 = metric_calculation(y_test, prediction)

    print(f"F1 Score: {round(f1 * 100, 2)}%", '\n')
    print(f"Precision: {round(pre * 100, 2)}%", '\n')
    print(f"Recall: {round(rec * 100, 2)}%", '\n')

    acc_per_fold.append(accuracy*100)
    f1_all.append(f1)
    pre_all.append(pre)
    rec_all.append(rec)
    history_all.append(history)

    fold_no = fold_no + 1
    if fold_no == 4: break
# Out:
#
# Training for fold 1 ...
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 4s 0us/step
# Epoch 1/100
# 226/226 [==============================] - 33s 77ms/step - loss: 1.3314 - accuracy: 0.5661 - val_loss: 0.7973 - val_accuracy: 0.6975
# Epoch 2/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.9236 - accuracy: 0.6426 - val_loss: 0.7449 - val_accuracy: 0.7146
# Epoch 3/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.8424 - accuracy: 0.6698 - val_loss: 0.6757 - val_accuracy: 0.7212
# Epoch 4/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.7656 - accuracy: 0.6976 - val_loss: 0.5916 - val_accuracy: 0.7633
# Epoch 5/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.7134 - accuracy: 0.7157 - val_loss: 0.6235 - val_accuracy: 0.7561
# Epoch 6/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.7128 - accuracy: 0.7237 - val_loss: 0.5849 - val_accuracy: 0.7688
# Epoch 7/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.6694 - accuracy: 0.7280 - val_loss: 0.5706 - val_accuracy: 0.7638
# Epoch 8/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.6506 - accuracy: 0.7436 - val_loss: 0.5504 - val_accuracy: 0.7887
# Epoch 9/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.6177 - accuracy: 0.7492 - val_loss: 0.5505 - val_accuracy: 0.7738
# Epoch 10/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.5892 - accuracy: 0.7666 - val_loss: 0.5233 - val_accuracy: 0.7898
# Epoch 11/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.5689 - accuracy: 0.7775 - val_loss: 0.5196 - val_accuracy: 0.7959
# Epoch 12/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.5296 - accuracy: 0.7929 - val_loss: 0.5422 - val_accuracy: 0.7959
# Epoch 13/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.5224 - accuracy: 0.7991 - val_loss: 0.5717 - val_accuracy: 0.7705
# Epoch 14/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.5102 - accuracy: 0.7942 - val_loss: 0.5063 - val_accuracy: 0.7998
# Epoch 15/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.5102 - accuracy: 0.8030 - val_loss: 0.4480 - val_accuracy: 0.8280
# Epoch 16/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.4802 - accuracy: 0.8117 - val_loss: 0.5058 - val_accuracy: 0.7970
# Epoch 17/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.4725 - accuracy: 0.8186 - val_loss: 0.4858 - val_accuracy: 0.8225
# Epoch 18/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.4513 - accuracy: 0.8281 - val_loss: 0.5204 - val_accuracy: 0.8219
# Epoch 19/100
# 226/226 [==============================] - 13s 59ms/step - loss: 0.4499 - accuracy: 0.8280 - val_loss: 0.4753 - val_accuracy: 0.8236
# Epoch 20/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.
100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1783 - accuracy: 0.9403 - val_loss: 0.5442 - val_accuracy: 0.8579
# Epoch 84/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1786 - accuracy: 0.9369 - val_loss: 0.4634 - val_accuracy: 0.8612
# Epoch 85/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1670 - accuracy: 0.9434 - val_loss: 0.4407 - val_accuracy: 0.8634
# Epoch 86/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1657 - accuracy: 0.9469 - val_loss: 0.5047 - val_accuracy: 0.8689
# Epoch 87/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1837 - accuracy: 0.9397 - val_loss: 0.4358 - val_accuracy: 0.8662
# Epoch 88/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1683 - accuracy: 0.9418 - val_loss: 0.5146 - val_accuracy: 0.8634
# Epoch 89/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1772 - accuracy: 0.9403 - val_loss: 0.5580 - val_accuracy: 0.8308
# Epoch 90/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1627 - accuracy: 0.9429 - val_loss: 0.5699 - val_accuracy: 0.8540
# Epoch 91/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1660 - accuracy: 0.9407 - val_loss: 0.5595 - val_accuracy: 0.8590
# Epoch 92/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1459 - accuracy: 0.9505 - val_loss: 0.4892 - val_accuracy: 0.8656
# Epoch 93/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1680 - accuracy: 0.9472 - val_loss: 0.6237 - val_accuracy: 0.8473
# Epoch 94/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1698 - accuracy: 0.9432 - val_loss: 0.5735 - val_accuracy: 0.8518
# Epoch 95/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1763 - accuracy: 0.9418 - val_loss: 0.5015 - val_accuracy: 0.8645
# Epoch 96/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1511 - accuracy: 0.9459 - val_loss: 0.5767 - val_accuracy: 0.8540
# Epoch 97/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1570 - accuracy: 0.9465 - val_loss: 0.5464 - val_accuracy: 0.8584
# Epoch 98/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1757 - accuracy: 0.9451 - val_loss: 0.5095 - val_accuracy: 0.8650
# Epoch 99/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1464 - accuracy: 0.9462 - val_loss: 0.4650 - val_accuracy: 0.8667
# Epoch 100/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.1613 - accuracy: 0.9468 - val_loss: 0.4969 - val_accuracy: 0.8534
# 57/57 [==============================] - 2s 40ms/step - loss: 0.4969 - accuracy: 0.8534
# Test accuracy: 85.34%
#
# 57/57 [==============================] - 4s 39ms/step
# F1 Score: 86.93%
#
# Precision: 88.84%
#
# Recall: 85.36%
#
#
# Training for fold 2 ...
#
# Epoch 1/100
# 226/226 [==============================] - 24s 75ms/step - loss: 1.3376 - accuracy: 0.5489 - val_loss: 0.7803 - val_accuracy: 0.6941
# Epoch 2/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.8958 - accuracy: 0.6621 - val_loss: 0.7250 - val_accuracy: 0.7019
# Epoch 3/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.8382 - accuracy: 0.6712 - val_loss: 0.6518 - val_accuracy: 0.7317
# Epoch 4/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.7646 - accuracy: 0.6994 - val_loss: 0.6917 - val_accuracy: 0.7124
# Epoch 5/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.7173 - accuracy: 0.7207 - val_loss: 0.6163 - val_accuracy: 0.7312
# Epoch 6/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.6727 - accuracy: 0.7304 - val_loss: 0.5947 - val_accuracy: 0.7400
# Epoch 7/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.6661 - accuracy: 0.7392 - val_loss: 0.5745 - val_accuracy: 0.7461
# Epoch 8/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.6364 - accuracy: 0.7504 - val_loss: 0.5721 - val_accuracy: 0.7533
# Epoch 9/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.6181 - accuracy: 0.7557 - val_loss: 0.5576 - val_accuracy: 0.7743
# Epoch 10/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0
100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.9035 - accuracy: 0.6514 - val_loss: 0.7101 - val_accuracy: 0.7157
# Epoch 3/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.8081 - accuracy: 0.6785 - val_loss: 0.6583 - val_accuracy: 0.7251
# Epoch 4/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.7599 - accuracy: 0.7049 - val_loss: 0.6162 - val_accuracy: 0.7351
# Epoch 5/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.7061 - accuracy: 0.7153 - val_loss: 0.5944 - val_accuracy: 0.7400
# Epoch 6/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.6803 - accuracy: 0.7290 - val_loss: 0.6337 - val_accuracy: 0.7262
# Epoch 7/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.6556 - accuracy: 0.7398 - val_loss: 0.5698 - val_accuracy: 0.7489
# Epoch 8/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.6219 - accuracy: 0.7583 - val_loss: 0.5567 - val_accuracy: 0.7683
# Epoch 9/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.6050 - accuracy: 0.7604 - val_loss: 0.5491 - val_accuracy: 0.7622
# Epoch 10/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.5787 - accuracy: 0.7667 - val_loss: 0.5539 - val_accuracy: 0.7821
# Epoch 11/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.5769 - accuracy: 0.7754 - val_loss: 0.5288 - val_accuracy: 0.7788
# Epoch 12/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.5391 - accuracy: 0.7922 - val_loss: 0.5061 - val_accuracy: 0.7987
# Epoch 13/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.5454 - accuracy: 0.7861 - val_loss: 0.5439 - val_accuracy: 0.7777
# Epoch 14/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.5205 - accuracy: 0.7944 - val_loss: 0.4815 - val_accuracy: 0.7987
# Epoch 15/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.4901 - accuracy: 0.8048 - val_loss: 0.5071 - val_accuracy: 0.8053
# Epoch 16/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.4825 - accuracy: 0.8160 - val_loss: 0.5589 - val_accuracy: 0.7976
# Epoch 17/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.4673 - accuracy: 0.8178 - val_loss: 0.4550 - val_accuracy: 0.8225
# Epoch 18/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.4378 - accuracy: 0.8269 - val_loss: 0.4897 - val_accuracy: 0.8075
# Epoch 19/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.4401 - accuracy: 0.8317 - val_loss: 0.4578 - val_accuracy: 0.8263
# Epoch 20/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.4336 - accuracy: 0.8296 - val_loss: 0.4505 - val_accuracy: 0.8208
# Epoch 21/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.4109 - accuracy: 0.8408 - val_loss: 0.4543 - val_accuracy: 0.8258
# Epoch 22/100
# 226/226 [==============================] - 13s 57ms/step - loss: 0.4093 - accuracy: 0.8432 - val_loss: 0.4273 - val_accuracy: 0.8407
# Epoch 23/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.4011 - accuracy: 0.8512 - val_loss: 0.5241 - val_accuracy: 0.8125
# Epoch 24/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.3799 - accuracy: 0.8529 - val_loss: 0.4765 - val_accuracy: 0.8258
# Epoch 25/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.3828 - accuracy: 0.8475 - val_loss: 0.4356 - val_accuracy: 0.8457
# Epoch 26/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.3600 - accuracy: 0.8659 - val_loss: 0.4289 - val_accuracy: 0.8446
# Epoch 27/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.3475 - accuracy: 0.8655 - val_loss: 0.4202 - val_accuracy: 0.8396
# Epoch 28/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.3479 - accuracy: 0.8715 - val_loss: 0.4623 - val_accuracy: 0.8291
# Epoch 29/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.3388 - accuracy: 0.8746 - val_loss: 0.4294 - val_accuracy: 0.8435
# Epoch 30/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.3337 - accuracy: 0.8764 - val_loss: 0.4658 - val_accuracy: 0.8313
# Epoch 31/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.
100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1635 - accuracy: 0.9441 - val_loss: 0.4286 - val_accuracy: 0.8733
# Epoch 94/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1689 - accuracy: 0.9451 - val_loss: 0.3969 - val_accuracy: 0.8617
# Epoch 95/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1672 - accuracy: 0.9432 - val_loss: 0.4015 - val_accuracy: 0.8794
# Epoch 96/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1304 - accuracy: 0.9564 - val_loss: 0.4360 - val_accuracy: 0.8673
# Epoch 97/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1562 - accuracy: 0.9457 - val_loss: 0.5384 - val_accuracy: 0.8667
# Epoch 98/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1616 - accuracy: 0.9441 - val_loss: 0.5351 - val_accuracy: 0.8595
# Epoch 99/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1515 - accuracy: 0.9498 - val_loss: 0.4344 - val_accuracy: 0.8567
# Epoch 100/100
# 226/226 [==============================] - 13s 58ms/step - loss: 0.1849 - accuracy: 0.9376 - val_loss: 0.4065 - val_accuracy: 0.8706
# 57/57 [==============================] - 2s 41ms/step - loss: 0.4065 - accuracy: 0.8706
# Test accuracy: 87.06%
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-17-7874846bb572> in <cell line: 7>()
#      48     print(f"Test accuracy: {round(accuracy * 100, 2)}%", '\n')
#      49
# ---> 50     prediction = model.predict(x_test)
#      51     pre, rec, f1 = metric_calculation(y_test, prediction)
#      52
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %% [markdown]
# ## Analysis

# %%
print(acc_per_fold, '\n')

mean = np.mean(np.array(acc_per_fold))
std = np.std(np.array(acc_per_fold))

print(f"Overall Accuracy is : {mean}+-{std}")
# Out:
# [85.34291982650757, 86.78097128868103]
#
# Overall Accuracy is : 86.0619455575943+-0.719025731086731

# %%
print(f1_all, '\n')

mean = np.mean(np.array(f1_all))
std = np.std(np.array(f1_all))

print(f"F1 Score is : {mean}+-{std}")
# Out:
# [0.86926717, 0.8737668]
#
# F1 Score is : 0.8715169429779053+-0.002249807119369507

# %%
print(pre_all, '\n')

mean = np.mean(np.array(pre_all))
std = np.std(np.array(pre_all))

print(f"Precision is : {mean}+-{std}")
# Out:
# [0.8883983, 0.88855565]
#
# Precision is : 0.8884769678115845+-7.867813110351562e-05

# %%
print(rec_all, '\n')

mean = np.mean(np.array(rec_all))
std = np.std(np.array(rec_all))

print(f"Recall is : {mean}+-{std}")
# Out:
# [0.85363656, 0.86247855]
#
# Recall is : 0.8580575585365295+-0.0044209957122802734

# %% [markdown]
# ## History an File Saving to Numpy Array

# %%
history_nparray = np.zeros((8, 100))
print(len(history_all[0].history))

count = 0

for k in tqdm(range(2)):

    aa = history_all[k].history      # Dictionary

    history_nparray[count, :] = np.array(aa['loss'])
    count = count+1
    history_nparray[count, :] = np.array(aa['accuracy'])
    count = count+1
    history_nparray[count, :] = np.array(aa['val_loss'])
    count = count+1
    history_nparray[count, :] = np.array(aa['val_accuracy'])
    count = count+1

print(count)
print(history_nparray[-1,:])
# Out:
# 4
#   0%|          | 0/2 [00:00<?, ?it/s]
# 8
# [0.69413716 0.70188051 0.73174781 0.71238941 0.73119467 0.74004424
#  0.74612832 0.75331861 0.77433628 0.77931416 0.78429204 0.81858408
#  0.80641592 0.81747788 0.82356197 0.80586284 0.82300884 0.82632744
#  0.82190263 0.81913716 0.82466817 0.83075219 0.7920354  0.81913716
#  0.8340708  0.85011059 0.84181416 0.84734511 0.84623891 0.81969029
#  0.84900445 0.86283183 0.86449116 0.84900445 0.85121679 0.8545354
#  0.84734511 0.85011059 0.8556416  0.86449116 0.85508847 0.83849555
#  0.86615044 0.86615044 0.8556416  0.85176992 0.85840708 0.87334073
#  0.86946905 0.87831861 0.87334073 0.86393803 0.86006635 0.8738938
#  0.86615044 0.86006635 0.87057525 0.87112832 0.852323   0.86615044
#  0.86172569 0.86504424 0.86227876 0.86891592 0.86836284 0.85730088
#  0.87444693 0.86615044 0.87057525 0.85508847 0.87942475 0.86946905
#  0.86172569 0.88772124 0.87002212 0.87776548 0.87168139 0.87002212
#  0.8738938  0.87057525 0.86780971 0.87721241 0.8738938  0.86670351
#  0.875      0.87555307 0.8761062  0.86117256 0.87112832 0.86780971
#  0.86559737 0.87168139 0.87721241 0.87997788 0.86061949 0.85951328
#  0.87334073 0.86670351 0.88108408 0.86780971]

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(100), history_nparray[5,:], label='Training Accuracy')
plt.plot(range(100), history_nparray[7,:], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(100), history_nparray[4,:], label='Training Loss')
plt.plot(range(100), history_nparray[6,:], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
np.save('/content/ResNet_ViT_9040_History_2.npy', history_nparray)

acc_f1_pre_rec = np.zeros((4,2))
acc_f1_pre_rec[0,:] = np.array(acc_per_fold)
acc_f1_pre_rec[1,:] = np.array(f1_all)
acc_f1_pre_rec[2,:] = np.array(pre_all)
acc_f1_pre_rec[3,:] = np.array(rec_all)

np.save('/content/ResNet_ViT_9040_Metric_2.npy', acc_f1_pre_rec)

# %%
print(y_test.shape, prediction.shape)
# Out:
# (1808, 5) (1808, 5)

# %%
print(y_test.shape)
print(prediction.shape)

y_pred = np.zeros((y_test.shape[0],5))
for i in range(y_test.shape[0]):
      indx = np.argmax(prediction[i,:])
      y_pred[i,indx] = 1

correct = 0
for i in range(y_pred.shape[0]):
    if np.sum(y_test[i,:]==y_pred[i,:]) == 5:
        correct = correct + 1
accuracy = correct / y_test.shape[0]
print(accuracy*100)

truelabel = []
predlabel = []

for i in range(y_test.shape[0]):
    if y_test[i, 0] == 1:
        truelabel.append("H1")
    if y_test[i, 1] == 1:
        truelabel.append("H2")
    if y_test[i, 2] == 1:
        truelabel.append("H3")
    if y_test[i, 3] == 1:
        truelabel.append("H5")
    if y_test[i, 4] == 1:
        truelabel.append("H6")
truelabel = np.array(truelabel)

for i in range(y_pred.shape[0]):
    if y_pred[i, 0] == 1:
        predlabel.append("H1")
    if y_pred[i, 1] == 1:
        predlabel.append("H2")
    if y_pred[i, 2] == 1:
        predlabel.append("H3")
    if y_pred[i, 3] == 1:
        predlabel.append("H5")
    if y_pred[i, 4] == 1:
        predlabel.append("H6")

truelabel = np.array(truelabel)
predlabel = np.array(predlabel)

temp = 0
for i in range(truelabel.shape[0]):
    if truelabel[i] == predlabel[i]: temp = temp + 1
print(temp*100/truelabel.shape[0])
# Out:
# (1808, 5)
# (1808, 5)
# 86.67035398230088
# 86.67035398230088

# %%
np.save('/content/ResNet_ViT_full_truelabel.npy', truelabel)
np.save('/content/ResNet_ViT_full_predlabel.npy', predlabel)
