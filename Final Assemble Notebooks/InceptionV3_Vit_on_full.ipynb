# %% [markdown]
# GPU

# %%
# !nvidia-smi
# Out:
# Sat Sep 23 13:08:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Importing Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf
import os
import numpy as np
import random
from tqdm.auto import tqdm
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from glob import glob
import cv2
from skimage.io import imread, imshow, show

from tensorflow import keras
from keras import layers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input

seed = 42
np.random.seed = seed  # To get same random seed everytime we run the whole thing.
tf.random.set_seed(42)
random.seed(seed)

# %%
# !pip install -U tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.21.0 typeguard-2.13.3

# %%
import tensorflow_addons as tfa

# %% [markdown]
# ## Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data Preparation

# %%
H1_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H1/*"
H2_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H2/*"
H3_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H3/*"
H5_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H5/*"
H6_path = "/content/drive/MyDrive/ICCIT 2023/Dataset/H6/*"

# %%
def sorted_file_paths(path):
    file_paths = sorted(glob(path))
    print("Total image files:")
    print(f"{len(file_paths)} \n")
    return file_paths

H1_file_paths = sorted_file_paths(H1_path)
H2_file_paths = sorted_file_paths(H2_path)
H3_file_paths = sorted_file_paths(H3_path)
H5_file_paths = sorted_file_paths(H5_path)
H6_file_paths = sorted_file_paths(H6_path)
# Out:
# Total image files:
# 4357
#
# Total image files:
# 2314
#
# Total image files:
# 816
#
# Total image files:
# 814
#
# Total image files:
# 739

# %%
all_file_paths = H1_file_paths + H2_file_paths + H3_file_paths + H5_file_paths + H6_file_paths
print(len(all_file_paths))
print(4357+2314+816+814+739)
# Out:
# 9040
# 9040

# %%
def image_preprocess(paths):
    total = len(paths)
    im_array = np.zeros((total, 224, 224, 3), dtype = np.float32)
    for i in tqdm(range(total)):
        img = imread(paths[i])  # Numpy Array = (500,500,3)
        # print(image.shape)
        img = cv2.resize(img, (224, 224))
        # img = img / 255.0
        im_array[i, :,:,:] = img
    return im_array

# X = image_preprocess(all_file_paths)
X = np.load("/content/drive/MyDrive/ICCIT 2023/npy_files/array_9040_224.npy")
print(X.shape)
print(X.dtype)
# Out:
# (9040, 224, 224, 3)
# float32

# %%
# np.save("/content/drive/MyDrive/ICCIT 2023/npy_files/array_9040_224.npy", X)

# %%
labels = ['H1']*4357 + ['H2']*2314 + ['H3']*816 + ['H5']*814 + ['H6']*739
print(type(labels))
print(len(labels))
# print(labels[3300])
# print(labels)
# Out:
# <class 'list'>
# 9040

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras

label_enconder = LabelEncoder()
y = label_enconder.fit_transform(labels)
print(y.shape)
print(y)
print('\n')


classes = list(label_enconder.classes_)
print(classes)
print('\n')
# Out:
# (9040,)
# [0 0 0 ... 4 4 4]
#
#
# ['H1', 'H2', 'H3', 'H5', 'H6']

# %%
X = np.array(X, dtype=np.float32)
y = np.array(y, dtype=np.float32)
print(X.shape, y.shape)
print(X.dtype, y.dtype)
# All are 4D and 1D array.
# Out:
# (9040, 224, 224, 3) (9040,)
# float32 float32

# %% [markdown]
# ## Vit Model creation

# %%
input_size = 224
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 30
num_epochs = 100
image_size = 72
patch_size = 6
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 4
mlp_head_units = [2048, 1024]

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)

# Compute the mean and the variance of the training data for normalization.
# data_augmentation.layers[0].adapt(x_train)



def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches


class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_part(input, aug_layer):

    # input_shape = (input_size, input_size, 3)
    # num_classes = 5
    # inputs = layers.Input(shape=input_shape)
    # Augment data.

    augmented = aug_layer(input)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)  #9216
    # Add MLP.
    # features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    # logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    # model = keras.Model(inputs=inputs, outputs=logits)

    x = layers.Dense(2048, activation=tf.nn.gelu)(representation)
    # x = layers.Dropout(0.5)(x)
    # x = layers.Dense(1024, activation=tf.nn.relu)(x)
    # x = layers.Dropout(0.5)(x)
    # x = layers.Dense(512, activation=tf.nn.relu)(x)

    return x  #2048

# vit_model = create_vit_classifier(data_augmentation)
# vit_model.summary()

# %% [markdown]
# ## Transfer Learning Model

# %%
def transfer_model(input):

    base_model = tf.keras.applications.inception_v3.InceptionV3(
                                                include_top=False,
                                                weights='imagenet',
                                                input_shape=(input_size, input_size, 3),
                                                pooling=None)

    base_model.trainable = False

    data_augmentation_vgg16 = keras.Sequential([layers.RandomFlip("horizontal"),
                                          layers.RandomRotation(factor=0.02),
                                          layers.RandomZoom(height_factor=0.1, width_factor=0.1)],
                                          name="vgg16_augmentation")

    vgg_preprocess = preprocess_input(input)
    x = data_augmentation_vgg16(vgg_preprocess)
    x = base_model(x, training=False)

    x = layers.GlobalAveragePooling2D()(x)
    # x = layers.Dropout(0.2)(x)
    # x = tf.keras.layers.Dense(1024,activation='relu')(x)
    # x = tf.keras.layers.Dropout(0.6)(x)
    # x = tf.keras.layers.Dense(512,activation='relu')(x)
    # x = tf.keras.layers.Dropout(0.5)(x)
    # output = tf.keras.layers.Dense(no_class, activation="softmax")(x)

    # model = keras.Model(inputs = input, outputs = x)

    return x

# input = keras.Input(shape=(input_size, input_size, 3))
# model = transfer_model(input)
# print(model.summary())

# %% [markdown]
# ## Casceding Model Creation

# %%
def Cascade_model(Vit_aug_layer):

    input = keras.Input(shape=(input_size, input_size, 3))  # (None, 224, 224, 3)
    num_classes = 5

    vit_output = create_vit_part(input, Vit_aug_layer)       #(None, 512)
    tranfer_output = transfer_model(input)    #(None, 512)

    multiplied = layers.Multiply()([vit_output, tranfer_output])
    x = layers.Dropout(0.5)(multiplied)

    x = tf.keras.layers.Dense(1024,activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(512,activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)

    output = tf.keras.layers.Dense(num_classes, activation="softmax")(x)

    model = keras.Model(inputs = input, outputs = output)

    return model

# %%
model = Cascade_model(data_augmentation)
model.summary()

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Training

# %%
def metric_calculation(true, out):

    f1_metric = tf.keras.metrics.F1Score()
    f1_metric.update_state(true, out)
    f1_scores = f1_metric.result().numpy()
    f1 = np.mean(f1_scores)

    pred = np.zeros((true.shape[0],5))
    for i in range(true.shape[0]):
        indx = np.argmax(out[i,:])
        pred[i,indx] = 1

    recall_scores = []
    pre_scores =[]
    for i in range(5):
        re_metric = tf.keras.metrics.Recall()
        pre_metric = tf.keras.metrics.Precision()
        re_metric.update_state(true[:,i],pred[:,i])
        pre_metric.update_state(true[:,i],pred[:,i])

        recall_scores.append(re_metric.result().numpy())
        pre_scores.append(pre_metric.result().numpy())

    recall = np.mean(np.array(recall_scores))
    precision = np.mean(np.array(pre_scores))

    return precision, recall, f1

# %%
acc_per_fold = []
history_all = []
f1_all = []
pre_all = []
rec_all = []

# %%
x_train = 0
# x_test =0
y_train = 0
# y_test = 0
# model = 0

# %%
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=44)

fold_no = 1


for train, test in cv.split(X, y):

    print('   ')
    print(f'Training for fold {fold_no} ...', '\n')

    x_train = X[train]
    x_test = X[test]
    y_train = y[train]
    y_test = y[test]

    y_train = tf.keras.utils.to_categorical(y_train, num_classes=5)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=5)

    data_augmentation_Vit = keras.Sequential([layers.Normalization(),
                                          layers.Resizing(image_size, image_size),
                                          layers.RandomFlip("horizontal"),
                                          layers.RandomRotation(factor=0.02),
                                          layers.RandomZoom(height_factor=0.2, width_factor=0.2)],
                                          name="vit_augmentation")


    data_augmentation_Vit.layers[0].adapt(x_train)

    model = Cascade_model(data_augmentation_Vit)

    optimizer = tfa.optimizers.AdamW(learning_rate=learning_rate,
                                     weight_decay=weight_decay)

    model.compile(optimizer=optimizer,
                  loss=keras.losses.CategoricalCrossentropy(from_logits=True),
                  metrics=[keras.metrics.CategoricalAccuracy(name="accuracy")])


    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data = (x_test, y_test))

    _, accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%", '\n')

    prediction = model.predict(x_test)
    pre, rec, f1 = metric_calculation(y_test, prediction)

    print(f"F1 Score: {round(f1 * 100, 2)}%", '\n')
    print(f"Precision: {round(pre * 100, 2)}%", '\n')
    print(f"Recall: {round(rec * 100, 2)}%", '\n')

    acc_per_fold.append(accuracy*100)
    f1_all.append(f1)
    pre_all.append(pre)
    rec_all.append(rec)
    history_all.append(history)

    fold_no = fold_no + 1
    # if fold_no == 2: break
# Out:
#
# Training for fold 1 ...
#
# Epoch 1/100
# 242/242 [==============================] - 52s 135ms/step - loss: 1.3773 - accuracy: 0.5329 - val_loss: 0.8505 - val_accuracy: 0.6571
# Epoch 2/100
# 242/242 [==============================] - 27s 113ms/step - loss: 0.9315 - accuracy: 0.6370 - val_loss: 0.7710 - val_accuracy: 0.6648
# Epoch 3/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.8461 - accuracy: 0.6634 - val_loss: 0.7108 - val_accuracy: 0.7107
# Epoch 4/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.7914 - accuracy: 0.6876 - val_loss: 0.7315 - val_accuracy: 0.6963
# Epoch 5/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.7329 - accuracy: 0.7071 - val_loss: 0.6533 - val_accuracy: 0.7290
# Epoch 6/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.7093 - accuracy: 0.7171 - val_loss: 0.6713 - val_accuracy: 0.7135
# Epoch 7/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.6831 - accuracy: 0.7282 - val_loss: 0.6945 - val_accuracy: 0.7235
# Epoch 8/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.6494 - accuracy: 0.7394 - val_loss: 0.6162 - val_accuracy: 0.7666
# Epoch 9/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.6364 - accuracy: 0.7481 - val_loss: 0.6043 - val_accuracy: 0.7483
# Epoch 10/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.6369 - accuracy: 0.7435 - val_loss: 0.6421 - val_accuracy: 0.7340
# Epoch 11/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.6101 - accuracy: 0.7553 - val_loss: 0.5522 - val_accuracy: 0.7749
# Epoch 12/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.
100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2738 - accuracy: 0.9021 - val_loss: 0.5408 - val_accuracy: 0.8208
# Epoch 73/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2475 - accuracy: 0.9114 - val_loss: 0.5215 - val_accuracy: 0.8385
# Epoch 74/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2502 - accuracy: 0.9136 - val_loss: 0.5721 - val_accuracy: 0.8352
# Epoch 75/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2385 - accuracy: 0.9145 - val_loss: 0.5116 - val_accuracy: 0.8396
# Epoch 76/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2400 - accuracy: 0.9134 - val_loss: 0.5948 - val_accuracy: 0.8191
# Epoch 77/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2586 - accuracy: 0.9071 - val_loss: 0.5826 - val_accuracy: 0.8313
# Epoch 78/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2263 - accuracy: 0.9208 - val_loss: 0.5767 - val_accuracy: 0.8274
# Epoch 79/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2451 - accuracy: 0.9147 - val_loss: 0.5319 - val_accuracy: 0.8324
# Epoch 80/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2317 - accuracy: 0.9168 - val_loss: 0.5250 - val_accuracy: 0.8225
# Epoch 81/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2410 - accuracy: 0.9162 - val_loss: 0.5503 - val_accuracy: 0.8274
# Epoch 82/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2214 - accuracy: 0.9186 - val_loss: 0.5531 - val_accuracy: 0.8280
# Epoch 83/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2211 - accuracy: 0.9198 - val_loss: 0.7068 - val_accuracy: 0.8142
# Epoch 84/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2488 - accuracy: 0.9165 - val_loss: 0.6296 - val_accuracy: 0.8164
# Epoch 85/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2019 - accuracy: 0.9239 - val_loss: 0.6395 - val_accuracy: 0.8153
# Epoch 86/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2302 - accuracy: 0.9162 - val_loss: 0.5697 - val_accuracy: 0.8263
# Epoch 87/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2381 - accuracy: 0.9168 - val_loss: 0.5290 - val_accuracy: 0.8280
# Epoch 88/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2195 - accuracy: 0.9249 - val_loss: 0.6906 - val_accuracy: 0.8131
# Epoch 89/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2258 - accuracy: 0.9238 - val_loss: 0.5250 - val_accuracy: 0.8131
# Epoch 90/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2176 - accuracy: 0.9263 - val_loss: 0.5183 - val_accuracy: 0.8352
# Epoch 91/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2192 - accuracy: 0.9291 - val_loss: 0.5035 - val_accuracy: 0.8291
# Epoch 92/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2305 - accuracy: 0.9234 - val_loss: 0.5460 - val_accuracy: 0.8352
# Epoch 93/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2057 - accuracy: 0.9295 - val_loss: 0.5396 - val_accuracy: 0.8324
# Epoch 94/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2032 - accuracy: 0.9284 - val_loss: 0.5616 - val_accuracy: 0.8269
# Epoch 95/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2071 - accuracy: 0.9251 - val_loss: 0.4629 - val_accuracy: 0.8429
# Epoch 96/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2056 - accuracy: 0.9270 - val_loss: 0.5246 - val_accuracy: 0.8413
# Epoch 97/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2261 - accuracy: 0.9248 - val_loss: 0.5099 - val_accuracy: 0.8313
# Epoch 98/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2179 - accuracy: 0.9259 - val_loss: 0.5281 - val_accuracy: 0.8457
# Epoch 99/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2164 - accuracy: 0.9267 - val_loss: 0.4903 - val_accuracy: 0.8385
# Epoch 100/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.2127 - accuracy: 0.9311 - val_loss: 0.4990 - val_accuracy: 0.8462
# 57/57 [==============================] - 8s 102ms/step - loss: 0.4990 - accuracy: 0.8462
# Test accuracy: 84.62%
#
# 57/57 [==============================] - 6s 77ms/step
# F1 Score: 85.26%
#
# Precision: 87.86%
#
# Recall: 83.68%
#
#
# Training for fold 2 ...
#
# Epoch 1/100
# 242/242 [==============================] - 42s 131ms/step - loss: 1.3751 - accuracy: 0.5384 - val_loss: 0.8491 - val_accuracy: 0.6560
# Epoch 2/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.9561 - accuracy: 0.6215 - val_loss: 0.7730 - val_accuracy: 0.6687
# Epoch 3/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.8559 - accuracy: 0.6601 - val_loss: 0.7239 - val_accuracy: 0.7157
# Epoch 4/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.8106 - accuracy: 0.6781 - val_loss: 0.7225 - val_accuracy: 0.7058
# Epoch 5/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.7753 - accuracy: 0.6941 - val_loss: 0.6476 - val_accuracy: 0.7362
# Epoch 6/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.7387 - accuracy: 0.7055 - val_loss: 0.6530 - val_accuracy: 0.7257
# Epoch 7/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.7128 - accuracy: 0.7178 - val_loss: 0.6653 - val_accuracy: 0.7235
# Epoch 8/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.6823 - accuracy: 0.7254 - val_loss: 0.6406 - val_accuracy: 0.7494
# Epoch 9/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.6567 - accuracy: 0.7431 - val_loss: 0.6280 - val_accuracy: 0.7472
# Epoch 10/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.6512 - accuracy: 0.7412 - val_loss: 0.6605 - val_accuracy: 0.7301
# Epoch 11/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.6111 - accuracy: 0.7558 - val_loss: 0.5932 - val_accuracy: 0.7727
# Epoch 12/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.6273 - accuracy: 0.7558 - val_loss: 0.6040 - val_accuracy: 0.7588
# Epoch 13/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.5732 - accuracy: 0.7683 - val_loss: 0.5960 - val_accuracy: 0.7605
# Epoch 14/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.5897 - accuracy: 0.7653 - val_loss: 0.6005 - val_accuracy: 0.7644
# Epoch 15/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.5643 - accuracy: 0.7730 - val_loss: 0.5720 - val_accuracy: 0.7821
# Epoch 16/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.5482 - accuracy: 0.7803 - val_loss: 0.6063 - val_accuracy: 0.7605
# Epoch 17/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.5960 - accuracy: 0.7750 - val_loss: 0.5884 - val_accuracy: 0.7721
# Epoch 18/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.5403 - accuracy: 0.7922 - val_loss: 0.5587 - val_accuracy: 0.7815
# Epoch 19/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.5304 - accuracy: 0.7842 - val_loss: 0.6107 - val_accuracy: 0.7854
# Epoch 20/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.5150 - accuracy: 0.7915 - val_loss: 0.5740 - val_accuracy: 0.7937
# Epoch 21/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.5011 - accuracy: 0.7989 - val_loss: 0.5703 - val_accuracy: 0.7777
# Epoch 22/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.5056 - accuracy: 0.8049 - val_loss: 0.5756 - val_accuracy: 0.7915
# Epoch 23/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.4737 - accuracy: 0.8162 - val_loss: 0.5513 - val_accuracy: 0.7738
# Epoch 24/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.4619 - accuracy: 0.8146 - val_loss: 0.5089 - val_accuracy: 0.8086
# Epoch 25/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.4457 - accuracy: 0.8238 - val_loss: 0.5018 - val_accuracy: 0.8048
# Epoch 26/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.4340 - accuracy: 0.8314 - val_loss: 0.5268 - val_accuracy: 0.8053
# Epoch 27/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.4179 - accuracy: 0.8384 - val_loss: 0.5281 - val_accuracy: 0.8020
# Epoch 28/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.4154 - accuracy: 0.8404 - val_loss: 0.5772 - val_accuracy: 0.7937
# Epoch 29/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.4159 - accuracy: 0.8436 - val_loss: 0.5149 - val_accuracy: 0.8064
# Epoch 30/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.4067 - accuracy: 0.8439 - val_loss: 0.5663 - val_accuracy: 0.7954
# Epoch 31/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.3971 - accuracy: 0.8500 - val_loss: 0.5374 - val_accuracy: 0.7987
# Epoch 32/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.3880 - accuracy: 0.8551 - val_loss: 0.5161 - val_accuracy: 0.8125
# Epoch 33/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.3787 - accuracy: 0.8617 - val_loss: 0.5311 - val_accuracy: 0.8103
# Epoch 34/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.3694 - accuracy: 0.8552 - val_loss: 0.5169 - val_accuracy: 0.8075
# Epoch 35/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.3819 - accuracy: 0.8599 - val_loss: 0.4931 - val_accuracy: 0.8186
# Epoch 36/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.3448 - accuracy: 0.8631 - val_loss: 0.5434 - val_accuracy: 0.8064
# Epoch 37/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.3309 - accuracy: 0.8760 - val_loss: 0.5332 - val_accuracy: 0.8108
# Epoch 38/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.3476 - accuracy: 0.8717 - val_loss: 0.4780 - val_accuracy: 0.8247
# Epoch 39/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.3440 - accuracy: 0.8761 - val_loss: 0.5455 - val_accuracy: 0.8175
# Epoch 40/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.3329 - accuracy: 0.8768 - val_loss: 0.5388 - val_accuracy: 0.8164
# Epoch 41/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.3073 - accuracy: 0.8811 - val_loss: 0.5612 - val_accuracy: 0.8114
# Epoch 42/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.3255 - accuracy: 0.8830 - val_loss: 0.4778 - val_accuracy: 0.8346
# Epoch 43/100
# 242/242 [==============================] - 28s 114ms/step - loss: 0.3087 - accuracy: 0.8873 - val_loss: 0.5191 - val_accuracy: 0.8108
# Epoch 44/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.3009 - accuracy: 0.8887 - val_loss: 0.5598 - val_accuracy: 0.8064
# Epoch 45/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.3026 - accuracy: 0.8895 - val_loss: 0.4691 - val_accuracy: 0.8396
# Epoch 46/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2986 - accuracy: 0.8912 - val_loss: 0.4779 - val_accuracy: 0.8319
# Epoch 47/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2721 - accuracy: 0.8953 - val_loss: 0.4636 - val_accuracy: 0.8385
# Epoch 48/100
# 242/242 [==============================] - 28s 116ms/step - loss: 0.2818 - accuracy: 0.8957 - val_loss: 0.4485 - val_accuracy: 0.8385
# Epoch 49/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2858 - accuracy: 0.8938 - val_loss: 0.4994 - val_accuracy: 0.8319
# Epoch 50/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2799 - accuracy: 0.8989 - val_loss: 0.4951 - val_accuracy: 0.8313
# Epoch 51/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2888 - accuracy: 0.8982 - val_loss: 0.5036 - val_accuracy: 0.8291
# Epoch 52/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2800 - accuracy: 0.8978 - val_loss: 0.5188 - val_accuracy: 0.8258
# Epoch 53/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2810 - accuracy: 0.8988 - val_loss: 0.4882 - val_accuracy: 0.8291
# Epoch 54/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2584 - accuracy: 0.9112 - val_loss: 0.5369 - val_accuracy: 0.8357
# Epoch 55/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2786 - accuracy: 0.8989 - val_loss: 0.5404 - val_accuracy: 0.8219
# Epoch 56/100
# 242/242 [==============================] - 28s 116ms/step - loss: 0.2744 - accuracy: 0.9011 - val_loss: 0.4961 - val_accuracy: 0.8335
# Epoch 57/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.
100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2786 - accuracy: 0.9010 - val_loss: 0.5729 - val_accuracy: 0.8274
# Epoch 88/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2222 - accuracy: 0.9255 - val_loss: 0.6320 - val_accuracy: 0.8164
# Epoch 89/100
# 242/242 [==============================] - 28s 116ms/step - loss: 0.2045 - accuracy: 0.9256 - val_loss: 0.5167 - val_accuracy: 0.8335
# Epoch 90/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.1844 - accuracy: 0.9320 - val_loss: 0.5706 - val_accuracy: 0.8219
# Epoch 91/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.1930 - accuracy: 0.9311 - val_loss: 0.5515 - val_accuracy: 0.8374
# Epoch 92/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.1980 - accuracy: 0.9353 - val_loss: 0.5764 - val_accuracy: 0.8263
# Epoch 93/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.1900 - accuracy: 0.9353 - val_loss: 0.5946 - val_accuracy: 0.8285
# Epoch 94/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.1940 - accuracy: 0.9331 - val_loss: 0.5399 - val_accuracy: 0.8324
# Epoch 95/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2188 - accuracy: 0.9262 - val_loss: 0.5119 - val_accuracy: 0.8396
# Epoch 96/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.1826 - accuracy: 0.9361 - val_loss: 0.5490 - val_accuracy: 0.8258
# Epoch 97/100
# 242/242 [==============================] - 28s 116ms/step - loss: 0.1812 - accuracy: 0.9416 - val_loss: 0.5538 - val_accuracy: 0.8302
# Epoch 98/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.1878 - accuracy: 0.9332 - val_loss: 0.5881 - val_accuracy: 0.8285
# Epoch 99/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2032 - accuracy: 0.9328 - val_loss: 0.5021 - val_accuracy: 0.8457
# Epoch 100/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.2054 - accuracy: 0.9299 - val_loss: 0.4920 - val_accuracy: 0.8507
# 57/57 [==============================] - 4s 78ms/step - loss: 0.4920 - accuracy: 0.8507
# Test accuracy: 85.07%
#
# 57/57 [==============================] - 7s 77ms/step
# F1 Score: 86.58%
#
# Precision: 87.14%
#
# Recall: 86.07%
#
#
# Training for fold 3 ...
#
# Epoch 1/100
# 242/242 [==============================] - 42s 132ms/step - loss: 1.4017 - accuracy: 0.5248 - val_loss: 0.8114 - val_accuracy: 0.6521
# Epoch 2/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.9853 - accuracy: 0.6145 - val_loss: 0.7671 - val_accuracy: 0.6737
# Epoch 3/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.8762 - accuracy: 0.6608 - val_loss: 0.7311 - val_accuracy: 0.6952
# Epoch 4/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.8126 - accuracy: 0.6851 - val_loss: 0.6891 - val_accuracy: 0.7030
# Epoch 5/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.7624 - accuracy: 0.6987 - val_loss: 0.6575 - val_accuracy: 0.7273
# Epoch 6/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.7201 - accuracy: 0.7135 - val_loss: 0.6037 - val_accuracy: 0.7506
# Epoch 7/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.7113 - accuracy: 0.7203 - val_loss: 0.6274 - val_accuracy: 0.7201
# Epoch 8/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.6798 - accuracy: 0.7306 - val_loss: 0.5797 - val_accuracy: 0.7616
# Epoch 9/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.6688 - accuracy: 0.7380 - val_loss: 0.6128 - val_accuracy: 0.7345
# Epoch 10/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.6345 - accuracy: 0.7380 - val_loss: 0.6078 - val_accuracy: 0.7467
# Epoch 11/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0.6261 - accuracy: 0.7540 - val_loss: 0.5728 - val_accuracy: 0.7721
# Epoch 12/100
# 242/242 [==============================] - 28s 116ms/step - loss: 0.5966 - accuracy: 0.7600 - val_loss: 0.5685 - val_accuracy: 0.7743
# Epoch 13/100
# 242/242 [==============================] - 28s 115ms/step - loss: 0
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-19-5ae7a0bec6de> in <cell line: 7>()
#      48     print(f"Test accuracy: {round(accuracy * 100, 2)}%", '\n')
#      49
# ---> 50     prediction = model.predict(x_test)
#      51     pre, rec, f1 = metric_calculation(y_test, prediction)
#      52
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
# prediction = model.predict(x_test)
# pre, rec, f1 = metric_calculation(y_test, prediction)

# print(f"F1 Score: {round(f1 * 100, 2)}%", '\n')
# print(f"Precision: {round(pre * 100, 2)}%", '\n')
# print(f"Recall: {round(rec * 100, 2)}%", '\n')

acc_per_fold.append(accuracy*100)
f1_all.append(f1)
pre_all.append(pre)
rec_all.append(rec)
history_all.append(history)

# %% [markdown]
# ## Analysis

# %%
print(acc_per_fold, '\n')

mean = np.mean(np.array(acc_per_fold))
std = np.std(np.array(acc_per_fold))

print(f"Overall Accuracy is : {mean}+-{std}")
# Out:
# [84.6238911151886, 85.06637215614319, 84.07079577445984, 84.07079577445984]
#
# Overall Accuracy is : 84.45796370506287+-0.4175795618058465

# %%
print(f1_all, '\n')

mean = np.mean(np.array(f1_all))
std = np.std(np.array(f1_all))

print(f"F1 Score is : {mean}+-{std}")
# Out:
# [0.8525648, 0.86579704, 0.86579704]
#
# F1 Score is : 0.8613862991333008+-0.006237733643501997

# %%
print(pre_all, '\n')

mean = np.mean(np.array(pre_all))
std = np.std(np.array(pre_all))

print(f"Precision is : {mean}+-{std}")
# Out:
# [0.87856466, 0.87138784, 0.87138784]
#
# Precision is : 0.8737800717353821+-0.0033831836190074682

# %%
print(rec_all, '\n')

mean = np.mean(np.array(rec_all))
std = np.std(np.array(rec_all))

print(f"Recall is : {mean}+-{std}")
# Out:
# [0.8368136, 0.86065876, 0.86065876]
#
# Recall is : 0.8527104258537292+-0.011240704916417599

# %%
print(len(history_all))
# Out:
# 4

# %% [markdown]
# ## History an File Saving to Numpy Array

# %%
history_nparray = np.zeros((16, 100))
print(len(history_all[0].history))

count = 0

for k in tqdm(range(4)):

    aa = history_all[k].history      # Dictionary

    history_nparray[count, :] = np.array(aa['loss'])
    count = count+1
    history_nparray[count, :] = np.array(aa['accuracy'])
    count = count+1
    history_nparray[count, :] = np.array(aa['val_loss'])
    count = count+1
    history_nparray[count, :] = np.array(aa['val_accuracy'])
    count = count+1

print(count)
print(history_nparray[-1,:])
# Out:
# 4
#   0%|          | 0/4 [00:00<?, ?it/s]
# 16
# [0.65210176 0.67367256 0.69524336 0.70298672 0.727323   0.75055307
#  0.72013277 0.76161504 0.73451328 0.74668139 0.77212387 0.77433628
#  0.75331861 0.78152657 0.79258847 0.77212387 0.772677   0.76327431
#  0.77820796 0.78761059 0.78761059 0.78484511 0.78042036 0.76438051
#  0.80530971 0.78042036 0.78871679 0.78595132 0.81803095 0.78042036
#  0.79480088 0.81913716 0.81969029 0.81084073 0.81637168 0.79148233
#  0.80973452 0.82300884 0.81747788 0.83075219 0.80862832 0.82190263
#  0.82798672 0.82853985 0.83075219 0.81858408 0.81858408 0.83462387
#  0.83075219 0.82190263 0.82853985 0.83130533 0.83019912 0.83628321
#  0.82190263 0.82300884 0.83628321 0.84679204 0.80696905 0.83904868
#  0.84347343 0.84015489 0.82300884 0.84015489 0.82577431 0.84015489
#  0.83904868 0.84513277 0.83573008 0.835177   0.83573008 0.83849555
#  0.84347343 0.82466817 0.83075219 0.84292036 0.83628321 0.85176992
#  0.83462387 0.835177   0.84457964 0.82964599 0.82743365 0.84568584
#  0.83794248 0.83075219 0.8318584  0.83351767 0.84347343 0.85398233
#  0.84236723 0.82743365 0.835177   0.83904868 0.85619467 0.84845132
#  0.83573008 0.83849555 0.84789824 0.84070796]

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(100), history_nparray[5,:], label='Training Accuracy')
plt.plot(range(100), history_nparray[7,:], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(100), history_nparray[4,:], label='Training Loss')
plt.plot(range(100), history_nparray[6,:], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
np.save('/content/InceptionV3_ViT_9040_History.npy', history_nparray)

acc_f1_pre_rec = np.zeros((4,3))
acc_f1_pre_rec[0,:] = np.array(acc_per_fold[:3])
acc_f1_pre_rec[1,:] = np.array(f1_all)
acc_f1_pre_rec[2,:] = np.array(pre_all)
acc_f1_pre_rec[3,:] = np.array(rec_all)

np.save('/content/InceptionV3_ViT_9040_Metric.npy', acc_f1_pre_rec)

# %%
print(y_test.shape, prediction.shape)
# Out:
# (1808, 5) (1808, 5)

# %%
print(y_test.shape)
print(prediction.shape)

y_pred = np.zeros((y_test.shape[0],5))
for i in range(y_test.shape[0]):
      indx = np.argmax(prediction[i,:])
      y_pred[i,indx] = 1

correct = 0
for i in range(y_pred.shape[0]):
    if np.sum(y_test[i,:]==y_pred[i,:]) == 5:
        correct = correct + 1
accuracy = correct / y_test.shape[0]
print(accuracy*100)

truelabel = []
predlabel = []

for i in range(y_test.shape[0]):
    if y_test[i, 0] == 1:
        truelabel.append("H1")
    if y_test[i, 1] == 1:
        truelabel.append("H2")
    if y_test[i, 2] == 1:
        truelabel.append("H3")
    if y_test[i, 3] == 1:
        truelabel.append("H5")
    if y_test[i, 4] == 1:
        truelabel.append("H6")
truelabel = np.array(truelabel)

for i in range(y_pred.shape[0]):
    if y_pred[i, 0] == 1:
        predlabel.append("H1")
    if y_pred[i, 1] == 1:
        predlabel.append("H2")
    if y_pred[i, 2] == 1:
        predlabel.append("H3")
    if y_pred[i, 3] == 1:
        predlabel.append("H5")
    if y_pred[i, 4] == 1:
        predlabel.append("H6")

truelabel = np.array(truelabel)
predlabel = np.array(predlabel)

temp = 0
for i in range(truelabel.shape[0]):
    if truelabel[i] == predlabel[i]: temp = temp + 1
print(temp*100/truelabel.shape[0])
# Out:
# (1808, 5)
# (1808, 5)
# 86.67035398230088
# 86.67035398230088

# %%
np.save('/content/ResNet_ViT_full_truelabel.npy', truelabel)
np.save('/content/ResNet_ViT_full_predlabel.npy', predlabel)
